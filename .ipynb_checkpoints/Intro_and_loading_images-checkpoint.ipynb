# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("images/andrew.jpg", cv2.IMREAD_GRAYSCALE)
#IMREAD_GRAYSCALE = 0
#IMREAD_COLOR     = 1
#IMREAD_UNCHANGED  = -1

# %%
cv2.imshow("image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite("images/grayAndrew.jpg", img)
# Out:
# True

# %%
#plt.imshow(img, cmap = "gray", interpolation = "bicubic")
plt.imshow(img, cmap = 'hot', interpolation = "spline36")
#plt.plot([50,100],[80,100], 'c', linewidth=5)
plt.show()
